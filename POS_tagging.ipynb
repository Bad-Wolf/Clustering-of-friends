# %%
import pandas as pd
import json
from sqlalchemy import create_engine
import pymysql
import pickle

# %%
data = pd.read_json("bulgarian_words.json", encoding="utf8")

# %%
data.head()
# Out:
#           type                                                url  \
# 0    male_noun  https://bg.wiktionary.org/wiki/%D0%A3%D0%B8%D0...
# 1  female_noun  https://bg.wiktionary.org/wiki/%D0%A3%D0%B8%D0...
# 2  middle_noun  https://bg.wiktionary.org/wiki/%D0%A3%D0%B8%D0...
# 3    adjective  https://bg.wiktionary.org/wiki/%D0%A3%D0%B8%D0...
# 4         verb  https://bg.wiktionary.org/wiki/%D0%A3%D0%B8%D0...
#
#                                                words
# 0  [хобит, орк, гоблин, абаджия, абажур, абанос, ...
# 1  [аба, абдикация, абдукция, аберация, абисинка,...
# 2  [абаджийство, абатство, абдикиране, абониране,...
# 3  [абаносов, абатски, абдоминален, абисински, аб...
# 4  [абдикирам, абонирам, абортирам, абсолютизирам...

# %%
columns = dict(zip(data.index, data.type))
data = data.words.apply(pd.Series).T.rename(columns=columns)

# %%
data.head()
# Out:
#   male_noun female_noun  middle_noun      adjective           verb  \
# 0     хобит         аба  абаджийство       абаносов      абдикирам
# 1       орк   абдикация     абатство        абатски       абонирам
# 2    гоблин    абдукция   абдикиране    абдоминален      абортирам
# 3   абаджия    аберация    абониране      абисински  абсолютизирам
# 4    абажур    абисинка   аборигенче  абитуриентски     абсорбирам
#
#            pronoun
# 0        абсолютно
# 1         абсурдно
# 2   авантюристично
# 3       автентично
# 4  автобиографично

# %%
for i in columns.values():
    print(i)
# Out:
# male_noun
# female_noun
# middle_noun
# adjective
# verb
# pronoun

# %%
for i in columns.values():
    print(data.notnull()[i].value_counts())
# Out:
# True     8858
# False    5310
# Name: male_noun, dtype: int64
# True     9965
# False    4203
# Name: female_noun, dtype: int64
# True     11652
# False     2516
# Name: middle_noun, dtype: int64
# True     12872
# False     1296
# Name: adjective, dtype: int64
# True    14168
# Name: verb, dtype: int64
# False    11420
# True      2748
# Name: pronoun, dtype: int64

# %%
# sqlEngine = create_engine('mysql+pymysql://root:pass@127.0.0.1', pool_recycle=3600)
# dbConnection = sqlEngine.connect()
# frame = pd.read_sql("select * from chitanka_rechko.derivative_form", dbConnection);
# pd.set_option('display.expand_frame_repr', False)
# dbConnection.close()

# with open('derivative_form.pickle', 'wb') as handle:
#     pickle.dump(frame, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('derivative_form.pickle', 'rb') as handle:
    derivative_form = pickle.load(handle)

# %%
derivative_form.shape
# Out:
# (4013667, 12)

# %%
print('\n'.join(list(derivative_form.description.unique())))
# Out:
# ед.ч.
# ед.ч. непълен член
# ед.ч. пълен член
# мн.ч.
# мн.ч. членувано
# бройна форма
# ед.ч. членувано
# м.р.
# м.р. непълен член
# м.р. пълен член
# ж.р.
# ж.р. членувано
# ср.р.
# ср.р. членувано
# звателна форма
# сег.вр., 1л., ед.ч.
# сег.вр., 1л., мн.ч.
# сег.вр., 2л., ед.ч.
# сег.вр., 2л., мн.ч.
# сег.вр., 3л., ед.ч.
# сег.вр., 3л., мн.ч.
# мин.св.вр., 1л., ед.ч.
# мин.св.вр., 1л., мн.ч.
# мин.св.вр., 2л., ед.ч.
# мин.св.вр., 2л., мн.ч.
# мин.св.вр., 3л., ед.ч.
# мин.св.вр., 3л., мн.ч.
# мин.несв.вр., 1л., ед.ч.
# мин.несв.вр., 1л., мн.ч.
# мин.несв.вр., 2л., ед.ч.
# мин.несв.вр., 2л., мн.ч.
# мин.несв.вр., 3л., ед.ч.
# мин.несв.вр., 3л., мн.ч.
# мин.неопр.вр., 1л., ед.ч., м.р.
# мин.неопр.вр., 1л., ед.ч., ж.р.
# мин.неопр.вр., 1л., ед.ч., ср.р.
# мин.неопр.вр., 1л., мн.ч.
# мин.неопр.вр., 2л., ед.ч., м.р.
# мин.неопр.вр., 2л., ед.ч., ж.р.
# мин.неопр.вр., 2л., ед.ч., ср.р.
# мин.неопр.вр., 2л., мн.ч.
# мин.неопр.вр., 3л., ед.ч., м.р.
# мин.неопр.вр., 3л., ед.ч., ж.р.
# мин.неопр.вр., 3л., ед.ч., ср.р.
# мин.неопр.вр., 3л., мн.ч.
# мин.пред.вр., 1л., ед.ч., м.р.
# мин.пред.вр., 1л., ед.ч., ж.р.
# мин.пред.вр., 1л., ед.ч., ср.р.
# мин.пред.вр., 1л., мн.ч.
# мин.пред.вр., 2л., ед.ч., м.р.
# мин.пред.вр., 2л., ед.ч., ж.р.
# мин.пред.вр., 2л., ед.ч., ср.р.
# мин.пред.вр., 2л., мн.ч.
# мин.пред.вр., 3л., ед.ч., м.р.
# мин.пред.вр., 3л., ед.ч., ж.р.
# мин.пред.вр., 3л., ед.ч., ср.р.
# мин.пред.вр., 3л., мн.ч.
# бъд.вр., 1л., ед.ч.
# бъд.вр., 1л., мн.ч.
# бъд.вр., 2л., ед.ч.
# бъд.вр., 2л., мн.ч.
# бъд.вр., 3л., ед.ч.
# бъд.вр., 3л., мн.ч.
# бъд.пред.вр., 1л., ед.ч., м.р.
# бъд.пред.вр., 1л., ед.ч., ж.р.
# бъд.пред.вр., 1л., ед.ч., ср.р.
# бъд.пред.вр., 1л., мн.ч.
# бъд.пред.вр., 2л., ед.ч., м.р.
# бъд.пред.вр., 2л., ед.ч., ж.р.
# бъд.пред.вр., 2л., ед.ч., ср.р.
# бъд.пред.вр., 2л., мн.ч.
# бъд.пред.вр., 3л., ед.ч., м.р.
# бъд.пред.вр., 3л., ед.ч., ж.р.
# бъд.пред.вр., 3л., ед.ч., ср.р.
# бъд.пред.вр., 3л., мн.ч.
# бъд.вр. в мин., 1л., ед.ч.
# бъд.вр. в мин., 1л., мн.ч.
# бъд.вр. в мин., 2л., ед.ч.
# бъд.вр. в мин., 2л., мн.ч.
# бъд.вр. в мин., 3л., ед.ч.
# бъд.вр. в мин., 3л., мн.ч.
# бъд.пред.вр. в мин., 1л., ед.ч., м.р.
# бъд.пред.вр. в мин., 1л., ед.ч., ж.р.
# бъд.пред.вр. в мин., 1л., ед.ч., ср.р.
# бъд.пред.вр. в мин., 1л., мн.ч.
# бъд.пред.вр. в мин., 2л., ед.ч., м.р.
# бъд.пред.вр. в мин., 2л., ед.ч., ж.р.
# бъд.пред.вр. в мин., 2л., ед.ч., ср.р.
# бъд.пред.вр. в мин., 2л., мн.ч.
# бъд.пред.вр. в мин., 3л., ед.ч., м.р.
# бъд.пред.вр. в мин., 3л., ед.ч., ж.р.
# бъд.пред.вр. в мин., 3л., ед.ч., ср.р.
# бъд.пред.вр. в мин., 3л., мн.ч.
# пр.накл., сег.вр., 1л., ед.ч., м.р.
# пр.накл., сег.вр., 1л., ед.ч., ж.р.
# пр.накл., сег.вр., 1л., ед.ч., ср.р.
# пр.накл., сег.вр., 1л., мн.ч.
# пр.накл., сег.вр., 2л., ед.ч., м.р.
# пр.накл., сег.вр., 2л., ед.ч., ж.р.
# пр.накл., сег.вр., 2л., ед.ч., ср.р.
# пр.накл., сег.вр., 2л., мн.ч.
# пр.накл., сег.вр., 3л., ед.ч., м.р.
# пр.накл., сег.вр., 3л., ед.ч., ж.р.
# пр.накл., сег.вр., 3л., ед.ч., ср.р.
# пр.накл., сег.вр., 3л., мн.ч.
# пр.накл., мин.св.вр., 1л., ед.ч., м.р.
# пр.накл., мин.св.вр., 1л., ед.ч., ж.р.
# пр.накл., мин.св.вр., 1л., ед.ч., ср.р.
# пр.накл., мин.св.вр., 1л., мн.ч.
# пр.накл., мин.св.вр., 2л., ед.ч., м.р.
# пр.накл., мин.св.вр., 2л., ед.ч., ж.р.
# пр.накл., мин.св.вр., 2л., ед.ч., ср.р.
# пр.накл., мин.св.вр., 2л., мн.ч.
# пр.накл., мин.св.вр., 3л., ед.ч., м.р.
# пр.накл., мин.св.вр., 3л., ед.ч., ж.р.
# пр.накл., мин.св.вр., 3л., ед.ч., ср.р.
# пр.накл., мин.св.вр., 3л., мн.ч.
# пр.накл., мин.неопр.вр., 1л., ед.ч., м.р.
# пр.накл., мин.неопр.вр., 1л., ед.ч., ж.р.
# пр.накл., мин.неопр.вр., 1л., ед.ч., ср.р.
# пр.накл., мин.неопр.вр., 1л., мн.ч.
# пр.накл., мин.неопр.вр., 2л., ед.ч., м.р.
# пр.накл., мин.неопр.вр., 2л., ед.ч., ж.р.
# пр.накл., мин.неопр.вр., 2л., ед.ч., ср.р.
# пр.накл., мин.неопр.вр., 2л., мн.ч.
# пр.накл., мин.неопр.вр., 3л., ед.ч., м.р.
# пр.накл., мин.неопр.вр., 3л., ед.ч., ж.р.
# пр.накл., мин.неопр.вр., 3л., ед.ч., ср.р.
# пр.накл., мин.неопр.вр., 3л., мн.ч.
# пр.накл., бъд.вр., 1л., ед.ч., м.р.
# пр.накл., бъд.вр., 1л., ед.ч., ж.р.
# пр.накл., бъд.вр., 1л., ед.ч., ср.р.
# пр.накл., бъд.вр., 1л., мн.ч.
# пр.накл., бъд.вр., 2л., ед.ч., м.р.
# пр.накл., бъд.вр., 2л., ед.ч., ж.р.
# пр.накл., бъд.вр., 2л., ед.ч., ср.р.
# пр.накл., бъд.вр., 2л., мн.ч.
# пр.накл., бъд.вр., 3л., ед.ч., м.р.
# пр.накл., бъд.вр., 3л., ед.ч., ж.р.
# пр.накл., бъд.вр., 3л., ед.ч., ср.р.
# пр.накл., бъд.вр., 3л., мн.ч.
# пр.накл., бъд.пред.вр., 1л., ед.ч., м.р.
# пр.накл., бъд.пред.вр., 1л., ед.ч., ж.р.
# пр.накл., бъд.пред.вр., 1л., ед.ч., ср.р.
# пр.накл., бъд.пред.вр., 1л., мн.ч.
# пр.накл., бъд.пред.вр., 2л., ед.ч., м.р.
# пр.накл., бъд.пред.вр., 2л., ед.ч., ж.р.
# пр.накл., бъд.пред.вр., 2л., ед.ч., ср.р.
# пр.накл., бъд.пред.вр., 2л., мн.ч.
# пр.накл., бъд.пред.вр., 3л., ед.ч., м.р.
# пр.накл., бъд.пред.вр., 3л., ед.ч., ж.р.
# пр.накл., бъд.пред.вр., 3л., ед.ч., ср.р.
# пр.накл., бъд.пред.вр., 3л., мн.ч.
# условно наклонение, 1л., ед.ч., м.р.
# условно наклонение, 1л., ед.ч., ж.р.
# условно наклонение, 1л., ед.ч., ср.р.
# условно наклонение, 1л., мн.ч.
# условно наклонение, 2л., ед.ч., м.р.
# условно наклонение, 2л., ед.ч., ж.р.
# условно наклонение, 2л., ед.ч., ср.р.
# условно наклонение, 2л., мн.ч.
# условно наклонение, 3л., ед.ч., м.р.
# условно наклонение, 3л., ед.ч., ж.р.
# условно наклонение, 3л., ед.ч., ср.р.
# условно наклонение, 3л., мн.ч.
# повелително наклонение, ед.ч.
# повелително наклонение, мн.ч.
# мин.деят.св.прич. м.р.
# мин.деят.св.прич. м.р. непълен член
# мин.деят.св.прич. м.р. пълен член
# мин.деят.св.прич. ж.р.
# мин.деят.св.прич. ж.р. членувано
# мин.деят.св.прич. ср.р.
# мин.деят.св.прич. ср.р. членувано
# мин.деят.св.прич. мн.ч.
# мин.деят.св.прич. мн.ч. членувано
# мин.деят.несв.прич. м.р.
# мин.деят.несв.прич. ж.р.
# мин.деят.несв.прич. ср.р.
# мин.деят.несв.прич. мн.ч.
# сег.деят.прич. м.р.
# сег.деят.прич. м.р. непълен член
# сег.деят.прич. м.р. пълен член
# сег.деят.прич. ж.р.
# сег.деят.прич. ж.р. членувано
# сег.деят.прич. ср.р.
# сег.деят.прич. ср.р. членувано
# сег.деят.прич. мн.ч.
# сег.деят.прич. мн.ч. членувано
# деепричастие
# мин.страд.прич. м.р.
# мин.страд.прич. м.р. непълен член
# мин.страд.прич. м.р. пълен член
# мин.страд.прич. ж.р.
# мин.страд.прич. ж.р. членувано
# мин.страд.прич. ср.р.
# мин.страд.прич. ср.р. членувано
# мин.страд.прич. мн.ч.
# мин.страд.прич. мн.ч. членувано
# именителен падеж
# винителен падеж
# винителен падеж, кратка форма
# дателен падеж
# дателен падеж, предложна форма
# дателен падеж, кратка форма
# м.р., ед.ч.
# м.р., ед.ч., непълен член
# м.р., ед.ч., пълен член
# ж.р., ед.ч.
# ж.р., ед.ч., членувано
# ср.р., ед.ч.
# ср.р., ед.ч., членувано
# мн.ч., членувано
# кратка форма
# м.р., мн.ч.
# м.р., мн.ч., членувано
# ж.р., мн.ч.
# ж.р., мн.ч., членувано
# ср.р., мн.ч.
# ср.р., мн.ч., членувано
# мъжколична форма
# мъжколична форма, членувано
# приблизителен брой
# приблизителен брой, членувано
# мъжка форма
# женска форма
# мин.деят.несв.прич. м.р. непълен член
# мин.деят.несв.прич. м.р. пълен член
# мин.деят.несв.прич. ж.р. членувано
# мин.деят.несв.прич. ср.р. членувано
# мин.деят.несв.прич. мн.ч. членувано

# %% [markdown]
# database - https://rechnik.chitanka.info/db.sql.gz

# %%
a = derivative_form.name.isin(data.male_noun)

# %%
data.male_noun.count()
# Out:
# 8858

# %%
derivative_form[derivative_form.name == "алилодидакт"]
# Out:
#               id         name name_stressed     name_broken name_condensed         description  is_infinitive  base_word_id  search_count corpus_rank corpus_count corpus_percent
# 4013641  4030770  алилодидакт          None  али-ло-ди-дакт         ллддкт               ед.ч.              1        119702             0        None         None           None
# 4013642  4030771  алилодидакт          None  али-ло-ди-дакт         ллддкт  ед.ч. непълен член              1        119702             0        None         None           None
# 4013643  4030772  алилодидакт          None  али-ло-ди-дакт         ллддкт    ед.ч. пълен член              1        119702             0        None         None           None
# 4013644  4030773  алилодидакт          None  али-ло-ди-дакт         ллддкт               мн.ч.              1        119702             0        None         None           None
# 4013645  4030774  алилодидакт          None  али-ло-ди-дакт         ллддкт     мн.ч. членувано              1        119702             0        None         None           None
# 4013646  4030775  алилодидакт          None  али-ло-ди-дакт         ллддкт        бройна форма              1        119702             0        None         None           None
# 4013647  4030776  алилодидакт          None  али-ло-ди-дакт         ллддкт      звателна форма              1        119702             0        None         None           None

# %%
# sqlEngine = create_engine('mysql+pymysql://root:pass@127.0.0.1', pool_recycle=3600)
# dbConnection = sqlEngine.connect()
# frame = pd.read_sql("select * from chitanka_rechko.word", dbConnection);
# pd.set_option('display.expand_frame_repr', False)
# dbConnection.close()
# with open('word.pickle', 'wb') as handle:
#     pickle.dump(frame, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# sqlEngine = create_engine('mysql+pymysql://root:pass@127.0.0.1', pool_recycle=3600)
# dbConnection = sqlEngine.connect()
# frame = pd.read_sql("select * from chitanka_rechko.word_type", dbConnection);
# pd.set_option('display.expand_frame_repr', False)
# dbConnection.close()
# with open('word_type.pickle', 'wb') as handle:
#     pickle.dump(frame, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('word.pickle', 'rb') as handle:
    word = pickle.load(handle)

# %%
with open('word_type.pickle', 'rb') as handle:
    word_type = pickle.load(handle)

# %%
word[word.id == 119702]
# Out:
#             id         name name_stressed     name_broken name_condensed                                           meaning synonyms classification  type_id pronounciation     ...     chitanka_count chitanka_percent chitanka_rank search_count source other_langs  deleted_at corpus_count corpus_percent corpus_rank
# 119674  119702  алилодидакт  алилодида`кт  али-ло-ди-дакт         ллддкт  +вж. [[алилодидактик]]\n+м. +Книж. взаимоучител.                               31                    ...               None             None          None           88   user                     NaT            0           None        None
#
# [1 rows x 23 columns]

# %%
import os
os.getcwd()

# %%
print(current_path)
# Out:
# C:\Users\Pavel Bogdanov\Desktop\SoftUni\Machine Learning\Final_project

# %%
word_type[word_type.id == 31].T
# Out:
#                                                              30
# id                                                           31
# name                                                        14a
# idi_number                                                   32
# speech_part                                           noun_male
# comment       Подтип със звателна форма. Въведен от Радостин...
# rules          к, [аъиеоуяюлр]к\nк\nка\nкът\nци\nците\nка\nко\n
# rules_test    академик\nакадемик\nакадемика\nакадемикът\nака...
# example_word                                         авиоманиак

# %%
word_type[word_type.name == "14a"].T
# Out:
#                                                              30
# id                                                           31
# name                                                        14a
# idi_number                                                   32
# speech_part                                           noun_male
# comment       Подтип със звателна форма. Въведен от Радостин...
# rules          к, [аъиеоуяюлр]к\nк\nка\nкът\nци\nците\nка\nко\n
# rules_test    академик\nакадемик\nакадемика\nакадемикът\nака...
# example_word                                         авиоманиак

# %%
word_type[word_type.speech_part == "adverb"]
# Out:
#       id name  idi_number speech_part comment rules rules_test example_word
# 269  273  188       445.0      adverb           0\n               инкогнито

# %%
word[word.type_id == 273]
# Out:
#             id             name      name_stressed            name_broken name_condensed                                            meaning                                           synonyms classification  type_id pronounciation     ...     chitanka_count chitanka_percent chitanka_rank search_count    source other_langs  deleted_at corpus_count corpus_percent corpus_rank
# 28511    28514        инкогнито         инко`гнито           ин-ког-ни-то          нкгнт  +нареч. За известни личности — под чуждо име и...                                              тайно           None      273           None     ...               None             None          None          100  eurodict        None         NaT            0           None        None
# 102984  102991        абсолютно         абсолю`тно           аб-со-лют-но          бслтн                                +вж. [[абсолю`тен]]  (прил.) безусловно, съвършено, неограничено, р...           None      273           None     ...               None             None          None          431  bgoffice        None         NaT            0           None        None
# 102985  102992         абсурдно          абсу`рдно            аб-сур-д-но          бсрдн                                               None   неуместно, глупаво, нелепо, неспособно, несръчно           None      273           None     ...               None             None          None          492  bgoffice        None         NaT            0           None        None
# 102986  102993   авантюристично    авантюристи`чно     аван-тю-рис-тич-но       внтрстчн                                               None                                               None           None      273           None     ...               None             None          None          146  bgoffice        None         NaT            0           None        None
# 102987  102994       автентично        автенти`чно          ав-тен-тич-но         втнтчн                                               None                                               None           None      273           None     ...               None             None          None          413  bgoffice        None         NaT            0           None        None
# 102988  102995  автобиографично  а`втобиографи`чно  ав-то-би-ог-ра-фич-но       втбгрфчн                                               None                                               None           None      273           None     ...               None             None          None          101  bgoffice        None         NaT            0           None        None
# 102989  102996      автоматично       автомати`чно        ав-то-ма-тич-но         втмтчн                              +вж. [[автомати`чен]]                                               None           None      273           None     ...               None             None          None          140  bgoffice        None         NaT            0           None        None
# 102990  102997        автономно         автоно`мно           ав-то-ном-но          втнмн                                               None                                               None           None      273           None     ...               None             None          None          119  bgoffice        None         NaT            0           None        None
# 102991  102998      авторитетно       авторите`тно        ав-то-ри-тет-но         втрттн                                               None                                               None           None      273           None     ...               None             None          None          107  bgoffice        None         NaT            0           None        None
# 102992  102999        адекватно         адеква`тно            адек-ват-но          дквтн                                               None                                               None           None      273           None     ...               None             None          None          170  bgoffice        None         NaT            0           None        None
# 102993  103000     алтруистично      алтруисти`чно      ал-т-ру-ис-тич-но        лтрстчн                                               None                                               None           None      273           None     ...               None             None          None          252  bgoffice        None         NaT            0           None        None
# 102994  103001       амбициозно        амбицио`зно         ам-би-ци-оз-но          мбцзн                                               None                                               None           None      273           None     ...               None             None          None          104  bgoffice        None         NaT            0           None        None
# 102995  103002      амбулаторно       амбулато`рно        ам-бу-ла-тор-но         мблтрн                                               None                                               None           None      273           None     ...               None             None          None          207  bgoffice        None         NaT            0           None        None
# 102996  103003    амфитеатрално     амфитеатра`лно     ам-фи-те-ат-рал-но        мфттрлн                                               None                                               None           None      273           None     ...               None             None          None          163  bgoffice        None         NaT            0           None        None
# 102997  103004       аналогично        аналоги`чно          ана-ло-гич-но          нлгчн                                               None                                               None           None      273           None     ...               None             None          None          211  bgoffice        None         NaT            0           None        None
# 102998  103005     анархистично      анархисти`чно        анар-хис-тич-но        нрхстчн                                               None                                               None           None      273           None     ...               None             None          None          112  bgoffice        None         NaT            0           None        None
# 102999  103006       анатомично        анатоми`чно          ана-то-мич-но          нтмчн                                               None                                               None           None      273           None     ...               None             None          None          140  bgoffice        None         NaT            0           None        None
# 103000  103007           анблок             анблок               ан-б-лок           нблк                                               None    изцяло, топтан, накуп, из един път, на един дъх           None      273           None     ...               None             None          None          346  bgoffice        None         NaT            0           None        None
# 103001  103008      анекдотично       анекдоти`чно         анек-до-тич-но         нкдтчн                                               None                                               None           None      273           None     ...               None             None          None          270  bgoffice        None         NaT            0           None        None
# 103002  103009             анти               анти                  ан-ти             нт                                               None                                               None           None      273           None     ...               None             None          None          167  bgoffice        None         NaT            0           None        None
# 103003  103010      антипатично       антипати`чно        ан-ти-па-тич-но         нтптчн                                               None                                               None           None      273           None     ...               None             None          None          124  bgoffice        None         NaT            0           None        None
# 103004  103011     антисептично      антисепти`чно       ан-ти-сеп-тич-но        нтсптчн                                               None                                               None           None      273           None     ...               None             None          None          123  bgoffice        None         NaT            0           None        None
# 103005  103012         апетитно          апети`тно             апе-тит-но           пттн                                               None                                               None           None      273           None     ...               None             None          None          113  bgoffice        None         NaT            0           None        None
# 103006  103013        апокрифно         апокри`фно            апок-риф-но          пкрфн                                               None                                               None           None      273           None     ...               None             None          None          477  bgoffice        None         NaT            0           None        None
# 103007  103014       аполитично       а`полити`чно          апо-ли-тич-но          плтчн                                               None                                               None           None      273           None     ...               None             None          None          130  bgoffice        None         NaT            0           None        None
# 103008  103015         априорно          априо`рно            ап-ри-ор-но           пррн                                               None                                               None           None      273           None     ...               None             None          None          422  bgoffice        None         NaT            0           None        None
# 103009  103016       ароматично         ароматично          аро-ма-тич-но          рмтчн                                               None                                               None           None      273           None     ...               None             None          None          100  bgoffice        None         NaT            0           None        None
# 103010  103017         ароматно          арома`тно             аро-мат-но           рмтн                                               None                                               None           None      273           None     ...               None             None          None          108  bgoffice        None         NaT            0           None        None
# 103011  103018       артистично        артисти`чно          ар-тис-тич-но         ртстчн                                               None                                               None           None      273           None     ...               None             None          None          130  bgoffice        None         NaT            0           None        None
# 103012  103019         архаично          архаи`чно            ар-ха-ич-но           рхчн                                               None                                               None           None      273           None     ...               None             None          None          159  bgoffice        None         NaT            0           None        None
# ...        ...              ...                ...                    ...            ...                                                ...                                                ...            ...      ...            ...     ...                ...              ...           ...          ...       ...         ...         ...          ...            ...         ...
# 105711  105718         щастливо          щастли`во            щас-т-ли-во          щстлв                                  +вж. [[щастли`в]]                                               None           None      273           None     ...               None             None          None          145  bgoffice        None         NaT            0           None        None
# 105712  105719          щателно           ща`телно              ща-тел-но           щтлн                                  +вж. [[ща`телен]]  внимателно, съсредоточено, строго\nподробно, о...           None      273           None     ...               None             None          None          110  bgoffice        None         NaT            0           None        None
# 105713  105720            щедро             ще`дро                 щед-ро            щдр                                    +вж. [[ще`дър]]  богато, обилно, изобилно, с пълни шепи\n(същ.)...           None      273           None     ...               None             None          None          140  bgoffice        None         NaT            0           None        None
# 105714  105721        щекотливо         щекотли`во           ще-кот-ли-во          щктлв                                               None                                               None           None      273           None     ...               None             None          None           92  bgoffice        None         NaT            0           None        None
# 105715  105722              щом                щом                    щом             щм  +съюз.\n#1 За въвеждане на подчинено изречение...  като, веднага като, щом като, когато\nсега ког...           None      273           None     ...               None             None          None          218  eurodict        None         NaT            0           None        None
# 105716  105723             щото              що`то                  що-то             щт  _относ. мест._ и +съюз.\n#1 +Остар. Каквото.\n...                                               None           None      273           None     ...               None             None          None           78  eurodict        None         NaT            0           None        None
# 105717  105724           щураво            щу`раво               щу-ра-во            щрв                                    +вж. [[щу`рав]]                                               None           None      273           None     ...               None             None          None           58  bgoffice        None         NaT            0           None        None
# 105718  105725          щурмови           щу`рмови              щур-мо-ви           щрмв                                               None                                               None           None      273           None     ...               None             None          None            0  bgoffice        None         NaT            0           None        None
# 105719  105726          ъглесто           ъ`глесто              ъг-лес-то           глст                                               None                                               None           None      273           None     ...               None             None          None           36  bgoffice        None         NaT            0           None        None
# 105720  105727         ъгловато          ъглова`то            ъг-ло-ва-то           глвт                                               None                                               None           None      273           None     ...               None             None          None           31  bgoffice        None         NaT            0           None        None
# 105721  105728         юбилейно           юбилейно             юби-лей-но            блн                                               None                                               None           None      273           None     ...               None             None          None           37  bgoffice        None         NaT            0           None        None
# 105722  105729       югозападно         югозападно          юго-за-пад-но          гзпдн                                               None                                               None           None      273           None     ...               None             None          None           31  bgoffice        None         NaT            0           None        None
# 105723  105730       югоизточно         югоизточно          юго-из-точ-но          гзтчн                                               None                                               None           None      273           None     ...               None             None          None           30  bgoffice        None         NaT            0           None        None
# 105724  105731             южно               южно                  юж-но             жн                                               None                                               None           None      273           None     ...               None             None          None           37  bgoffice        None         NaT            0           None        None
# 105725  105732           юначно             юначно                юнач-но            нчн                                               None                                               None           None      273           None     ...               None             None          None           55  bgoffice        None         NaT            0           None        None
# 105726  105733             юруш              юру`ш                   юруш             рш  +м., само +ед. +Остар.\n#1 Нападение, атака, п...                                               None           None      273           None     ...               None             None          None          119  eurodict        None         NaT            0           None        None
# 105727  105734             яваш              ява`ш                   яваш             вш  +прил., +неизм. +Разг. За тютюн — който не е с...                                               None           None      273           None     ...               None             None          None           38  eurodict        None         NaT            0           None        None
# 105728  105735             явно              я`вно                  яв-но             вн                                               None  открито, очевидно, видно, забележително, лично...           None      273           None     ...               None             None          None          191  bgoffice        None         NaT            0           None        None
# 105729  105736             ядно              я`дно                  яд-но             дн                                               None                             горчиво, горко, злобно           None      273           None     ...               None             None          None          177  bgoffice        None         NaT            0           None        None
# 105730  105737          ядовито           ядови`то              ядо-ви-то            двт                                   +вж. [[ядови`т]]                                               None           None      273           None     ...               None             None          None           45  bgoffice        None         NaT            0           None        None
# 105731  105738          ядосано           ядо`сано              ядо-са-но            дсн                                               None                                               None           None      273           None     ...               None             None          None           57  bgoffice        None         NaT            0           None        None
# 105732  105739        язвително         язви`телно           яз-ви-тел-но          звтлн                                +вж. [[язви`телен]]                                               None           None      273           None     ...               None             None          None           78  bgoffice        None         NaT            0           None        None
# 105733  105740            яката             я`ката                 яка-та             кт  +нареч. +Разг. Силно, много, здраво. _Трябва я...                       здравата, силно, кораво, яко           None      273           None     ...               None             None          None           47  eurodict        None         NaT            0           None        None
# 105734  105741              яко               я`ко                    яко              к  +нареч. +Разг.\n#1 Здраво, здравата; яката.\n#...            здраво, силно, стегнато, плътно, трайно           None      273           None     ...               None             None          None          193  eurodict        None         NaT            0           None        None
# 105735  105742             ярко              я`рко                  яр-ко             рк                                               None                           светло, блестящо, весело           None      273           None     ...               None             None          None          108  bgoffice        None         NaT            0           None        None
# 105736  105743          яростно           я`ростно              ярос-т-но           рстн                                               None                                  с все сила, бясно           None      273           None     ...               None             None          None          104  bgoffice        None         NaT            0           None        None
# 105737  105744             ясно              я`сно                  яс-но             сн                                               None  изрично, категорично, точно\nкратко, сбито, ст...           None      273           None     ...               None             None          None          401  bgoffice        None         NaT            0           None        None
# 114456  114477          миш-маш          ми`ш-ма`ш                миш-маш           мшмш        Объркано, хаотично. _Всичко стана миш-маш._  бъркотия, безредие, хаос, неразбория\nбърканиц...           None      273           None     ...               None             None          None            0  eurodict        None         NaT            0           None        None
# 114927  114949         най-вече         на`й-ве`че              най-ве-че            нвч  +нареч. Най-много, преди всичко. _Обичам всичк...  най-много, особено, предимно, преди всичко, гл...           None      273           None     ...               None             None          None          173  eurodict        None         NaT            0           None        None
# 119556  119584             сума              су`ма                  су-ма             см         +Разг. Много, доста. _Похарчих сума пари._               много, голямо количество, изобилно\n                     273                    ...               None             None          None            0      user        None         NaT            0           None        None
#
# [2757 rows x 23 columns]

# %%
# edge cases - миш-маш, най-вечe
# наречия/прилагателни?

# %%
import spacy

# %%
from spacy.lang.en.examples import sentences

# %%
from spacy.lang import en

# %%
nlp = spacy.load('en')

# %%
doc = nlp(sentences[0])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple is looking at buying U.K. startup for $1 billion
# Apple PROPN nsubj
# is VERB aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be VERB VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP compound X.X. False False
# startup startup NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
# Out:
# <function Doc.to_array>
